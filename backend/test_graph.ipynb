# %%
from IPython.display import Image, display
from graph import super_graph

display(Image(super_graph.get_graph().draw_mermaid_png()))

# %%
from IPython.display import Image, display
from graph import paper_writing_graph
  
display(Image(paper_writing_graph.get_graph().draw_mermaid_png()))

# %%
from IPython.display import Image, display
from graph import research_graph

display(Image(research_graph.get_graph().draw_mermaid_png()))

# %%
print("开始流式输出...")
full_response = ""

try:
    input_data = {
        # "messages": [("user", "先帮我查看上海未来30天的天气，得到数据后输出折线图。")],
        # "messages": [("user", "9.14和9.8，哪个更大？")],
        "messages": [("user", "现在是2025年11月，后弦下一场演唱会是什么时候？")],
    }
    
    async for step in super_graph.astream(input_data):
        print(f"步骤: {step}")
        
        for node, output in step.items():
            print(f"【{node}】执行结果：")
            if "messages" in output:
                full_response += output["messages"][-1].content
                print(output["messages"][-1].content)
            elif "next" in output:
                print(f"下一步：{output['next']}")
        print("---")
            
except Exception as e:
    print(f"发生错误: {e}")
# Out:
# 开始流式输出...
# 监督者响应: {"next": "research_team"}
# ✅ 监督者决定下一步: research_team
# 步骤: {'supervisor': {'next': 'research_team'}}
# 【supervisor】执行结果：
# 下一步：research_team
# ---
#
# 🔬 研究团队 开始工作...
# 监督者响应: {"next": "search"}
# ✅ 监督者决定下一步: search
# 📦 🔬 研究团队 块: ['supervisor']
# 🔍 监督者数据: {'next': 'search'}
# 🔍 联网搜索中...
# 我来帮您搜索后弦的最新演唱会信息。让我再搜索更具体的信息，看看是否有后弦2025年11月之后的演唱会安排。根据搜索结果，我找到了关于后弦演唱会的信息：
#
# ## 后弦下一场演唱会信息
#
# 根据搜索结果，后弦的下一场演唱会安排如下：
#
# **上海站**
# - **时间**：2025年12月20日 19:00
# - **地点**：国家会展中心(上海)虹馆EH
# - **主题**：后弦2025「从你的青春路过」Live演唱会-上海站
# - **状态**：售票中
#
# **已完成的演唱会**
# - **北京站**：2025年8月23日（已结束）
# - **南京站**：2024年12月21日（已结束）
#
# 目前看来，2025年12月20日的上海演唱会是后弦在2025年11月之后最近的一场演唱会。如果您想参加，现在就可以开始购票了。
#
# 建议您关注后弦的官方社交媒体账号或票务平台，以获取最新的演唱会信息和可能的加场消息。
# ✅ 🔍 联网搜索 完成
# 📦 🔬 研究团队 块: ['search']
# 监督者响应: {"next": "FINISH"}
# 🎯 监督者决定生成最终回答
# 🤖 生成最终回答...
# 根据最新信息，后弦的下一场演唱会安排如下：
#
# **上海站**
# - **时间**：2025年12月20日 19:00
# - **地点**：国家会展中心（上海）虹馆EH
# - **主题**：后弦2025「从你的青春路过」Live演唱会-上海站
# - **状态**：目前售票中
#
# ...
